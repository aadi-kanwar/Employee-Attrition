# %% [markdown]
# <a href="https://colab.research.google.com/github/aadi-kanwar/Employee-Attrition/blob/main/Employee_Attrition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## About Dataset¶
# **EmployeeID:** Unique identifier for each employee.
#
# **FirstName:** The first name of the employee.
#
# **LastName:** The last name of the employee.
#
# **Gender:** The gender of the employee.
#
# **Age:** The age of the employee.
#
# **BusinessTravel:** The frequency of business travel for the employee.
#
# **Department:** The department in which the employee works.
#
# **DistanceFromHome (KM)**: The distance between the employee's home and workplace in kilometers.
#
# **State**: The state in which the employee resides.
# Ethnicity: The ethnicity of the employee.
#
# **MaritalStatus**: The marital status of the employee.
#
# **Salary**: The annual salary of the employee.
#
# **StockOptionLevel**: The level of stock options granted to the employee.
#
# **OverTime**: Whether the employee works overtime (Yes/No).
#
# **HireDate**: The date the employee was hired.
#
# **Attrition**: Whether the employee has left the company (Yes/No).
#
# **YearsAtCompany**: The number of years the employee has been with the company.
#
# **YearsInMostRecentRole**: The number of years the employee has been in their most recent role.
#
# **YearsSinceLastPromotion**: The number of years since the employee's last promotion.
#
# **YearsWithCurrManager**: The number of years the employee has worked with their current manager.
#
# **EducationLevelID**: Unique identifier for the education level.
#
# **EducationLevel**: The level of education achieved, ranging from "No Formal Qualifications" to "Doctorate."

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Datasets/Employee.csv')

# %%
df
# Out:
#      EmployeeID   FirstName     LastName      Gender  Age BusinessTravel  \
# 0     3012-1A41    Leonelle        Simco      Female   30    Some Travel
# 1     CBCB-9C9D     Leonerd        Aland        Male   38    Some Travel
# 2     95D7-1CE9       Ahmed        Sykes        Male   43    Some Travel
# 3     47A0-559B  Ermentrude       Berrie  Non-Binary   39    Some Travel
# 4     42CC-040A       Stace       Savege      Female   29    Some Travel
# ...         ...         ...          ...         ...  ...            ...
# 1465  467E-977A         Jud    Melanaphy        Male   20    Some Travel
# 1466  6FB9-A624        Marc       Calver  Non-Binary   27    Some Travel
# 1467  EBF4-5928     Rudolph  MacDearmont        Male   21    Some Travel
# 1468  60E6-B1D9      Merill          Agg        Male   21    Some Travel
# 1469  84D4-D4C3       Naoma      Hebbard      Female   20     No Travel
#
#            Department  DistanceFromHome (KM) State                  Ethnicity  \
# ...

# %%
df.columns
# Out:
# Index(['EmployeeID', 'FirstName', 'LastName', 'Gender', 'Age',
#        'BusinessTravel', 'Department', 'DistanceFromHome (KM)', 'State',
#        'Ethnicity', 'Education', 'EducationField', 'JobRole', 'MaritalStatus',
#        'Salary', 'StockOptionLevel', 'OverTime', 'HireDate', 'Attrition',
#        'YearsAtCompany', 'YearsInMostRecentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.head()
# Out:
#   EmployeeID   FirstName LastName      Gender  Age BusinessTravel  \
# 0  3012-1A41    Leonelle    Simco      Female   30    Some Travel
# 1  CBCB-9C9D     Leonerd    Aland        Male   38    Some Travel
# 2  95D7-1CE9       Ahmed    Sykes        Male   43    Some Travel
# 3  47A0-559B  Ermentrude   Berrie  Non-Binary   39    Some Travel
# 4  42CC-040A       Stace   Savege      Female   29    Some Travel
#
#         Department  DistanceFromHome (KM) State                Ethnicity  ...  \
# 0            Sales                     27    IL                    White  ...
# 1            Sales                     23    CA                    White  ...
# 2  Human Resources                     29    CA  Asian or Asian American  ...
# 3       Technology                     12    IL                    White  ...
# 4  Human Resources                     29    CA                    White  ...
#
#    MaritalStatus  Salary StockOptionLevel OverTime    HireDate  Attrition  \
# ...

# %%
df.tail()
# Out:
#      EmployeeID FirstName     LastName      Gender  Age BusinessTravel  \
# 1465  467E-977A       Jud    Melanaphy        Male   20    Some Travel
# 1466  6FB9-A624      Marc       Calver  Non-Binary   27    Some Travel
# 1467  EBF4-5928   Rudolph  MacDearmont        Male   21    Some Travel
# 1468  60E6-B1D9    Merill          Agg        Male   21    Some Travel
# 1469  84D4-D4C3     Naoma      Hebbard      Female   20     No Travel
#
#       Department  DistanceFromHome (KM) State                  Ethnicity  ...  \
# 1465  Technology                     28    CA  Black or African American  ...
# 1466  Technology                      8    CA  Black or African American  ...
# 1467       Sales                      4    CA  Black or African American  ...
# 1468  Technology                      7    CA  Black or African American  ...
# 1469  Technology                     28    CA  Black or African American  ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeID               1470 non-null   object
#  1   FirstName                1470 non-null   object
#  2   LastName                 1470 non-null   object
#  3   Gender                   1470 non-null   object
#  4   Age                      1470 non-null   int64
#  5   BusinessTravel           1470 non-null   object
#  6   Department               1470 non-null   object
#  7   DistanceFromHome (KM)    1470 non-null   int64
#  8   State                    1470 non-null   object
#  9   Ethnicity                1470 non-null   object
#  10  Education                1470 non-null   int64
#  11  EducationField           1470 non-null   object
#  12  JobRole                  1470 non-null   object
#  13  MaritalStatus            1470 non-null   object
# ...

# %% [markdown]
# ## Data Types
# ### Categorical Variables:
# Gender, BusinessTravel, Department, State, Ethnicity, EducationField, JobRole, MaritalStatus, OverTime, Attrition.
#
# ### Numerical Variables:
# Age, DistanceFromHome, Education, Salary, StockOptionLevel, YearsAtCompany, YearsInMostRecentRole, YearsSinceLastPromotion, YearsWithCurrManager.
#
# ### Date Variable:
# HireDate.

# %%
df.describe()
# Out:
#                Age  DistanceFromHome (KM)    Education         Salary  \
# count  1470.000000            1470.000000  1470.000000    1470.000000
# mean     28.989796              22.502721     2.912925  112956.497959
# std       7.993055              12.811124     1.024165  103342.889222
# min      18.000000               1.000000     1.000000   20387.000000
# 25%      23.000000              12.000000     2.000000   43580.500000
# 50%      26.000000              22.000000     3.000000   71199.500000
# 75%      34.000000              33.000000     4.000000  142055.750000
# max      51.000000              45.000000     5.000000  547204.000000
#
#        StockOptionLevel  YearsAtCompany  YearsInMostRecentRole  \
# count       1470.000000     1470.000000            1470.000000
# mean           0.793878        4.562585               2.293197
# std            0.852077        3.288048               2.539093
# min            0.000000        0.000000               0.000000
# ...

# %%
df.describe(include='all')
# Out:
#        EmployeeID FirstName LastName  Gender          Age BusinessTravel  \
# count        1470      1470     1470    1470  1470.000000           1470
# unique       1470      1334     1441       4          NaN              3
# top     3012-1A41   Murdock   Ponten  Female          NaN    Some Travel
# freq            1         3        2     675          NaN           1043
# mean          NaN       NaN      NaN     NaN    28.989796            NaN
# std           NaN       NaN      NaN     NaN     7.993055            NaN
# min           NaN       NaN      NaN     NaN    18.000000            NaN
# 25%           NaN       NaN      NaN     NaN    23.000000            NaN
# 50%           NaN       NaN      NaN     NaN    26.000000            NaN
# 75%           NaN       NaN      NaN     NaN    34.000000            NaN
# max           NaN       NaN      NaN     NaN    51.000000            NaN
#
#         Department  DistanceFromHome (KM) State Ethnicity  ...  MaritalStatus  \
# ...

# %%
df.describe(include='object')
# Out:
#        EmployeeID FirstName LastName  Gender BusinessTravel  Department State  \
# count        1470      1470     1470    1470           1470        1470  1470
# unique       1470      1334     1441       4              3           3     3
# top     3012-1A41   Murdock   Ponten  Female    Some Travel  Technology    CA
# freq            1         3        2     675           1043         961   875
#
#        Ethnicity    EducationField          JobRole MaritalStatus OverTime  \
# count       1470              1470             1470          1470     1470
# unique         7                 9               13             3        2
# top        White  Computer Science  Sales Executive       Married       No
# freq         860               440              327           624     1054
#
#           HireDate Attrition
# count         1470      1470
# unique        1192         2
# top     2016-10-04        No
# freq             4      1233

# %% [markdown]
# ## Data Pre-processing

# %% [markdown]
# ### Checking null values

# %%
df.isnull().sum()
# Out:
# EmployeeID                 0
# FirstName                  0
# LastName                   0
# Gender                     0
# Age                        0
# BusinessTravel             0
# Department                 0
# DistanceFromHome (KM)      0
# State                      0
# Ethnicity                  0
# Education                  0
# EducationField             0
# JobRole                    0
# MaritalStatus              0
# Salary                     0
# StockOptionLevel           0
# OverTime                   0
# HireDate                   0
# Attrition                  0
# YearsAtCompany             0
# YearsInMostRecentRole      0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# dtype: int64

# %% [markdown]
# ### Checking duplicates in data

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Converting Datatype

# %%
df['HireDate'] = df['HireDate'].astype('datetime64[ns]')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeID               1470 non-null   object
#  1   FirstName                1470 non-null   object
#  2   LastName                 1470 non-null   object
#  3   Gender                   1470 non-null   object
#  4   Age                      1470 non-null   int64
#  5   BusinessTravel           1470 non-null   object
#  6   Department               1470 non-null   object
#  7   DistanceFromHome (KM)    1470 non-null   int64
#  8   State                    1470 non-null   object
#  9   Ethnicity                1470 non-null   object
#  10  Education                1470 non-null   int64
#  11  EducationField           1470 non-null   object
#  12  JobRole                  1470 non-null   object
#  13  MaritalStatus            1470 non-null   object
# ...

# %% [markdown]
# ## Calculate the percentage of employees who have left the company

# %%
attrition_rate = df['Attrition'].value_counts(normalize=True) * 100
print(attrition_rate)
# Out:
# Attrition
# No     83.877551
# Yes    16.122449
# Name: proportion, dtype: float64

# %% [markdown]
# ## Analyzing different factors

# %% [markdown]
# ### Analyze if factors like age affect the Attrition Rate

# %%
df.groupby(['Attrition'])['Age'].mean()
# Out:
# Attrition
# No     29.460665
# Yes    26.540084
# Name: Age, dtype: float64

# %% [markdown]
# ### Analyze if factors like department affect attrition rates

# %%
df.groupby(['Attrition'])['Department'].value_counts(normalize = True)
# Out:
# Attrition  Department
# No         Technology         0.671533
#            Sales              0.287105
#            Human Resources    0.041363
# Yes        Technology         0.561181
#            Sales              0.388186
#            Human Resources    0.050633
# Name: proportion, dtype: float64

# %% [markdown]
# ### Analyze if factors like job role affect attrition rates

# %%
df.groupby(['Attrition'])['JobRole'].value_counts(normalize=True)
# Out:
# Attrition  JobRole
# No         Sales Executive              0.218978
#            Software Engineer            0.200324
#            Data Scientist               0.161395
#            Machine Learning Engineer    0.110300
#            Senior Software Engineer     0.099757
#            Engineering Manager          0.059205
#            Sales Representative         0.040552
#            Analytics Manager            0.039740
#            Manager                      0.028386
#            HR Executive                 0.020276
#            Recruiter                    0.012165
#            HR Business Partner          0.005677
#            HR Manager                   0.003244
# Yes        Data Scientist               0.261603
#            Sales Executive              0.240506
#            Software Engineer            0.198312
#            Sales Representative         0.139241
#            Machine Learning Engineer    0.042194
#            Recruiter                    0.037975
# ...

# %% [markdown]
# ### Analyze if factors like salary affect attrition rates

# %%
df.groupby(['Attrition'])['Salary'].value_counts(normalize=True)
# Out:
# Attrition  Salary
# No         26973     0.001622
#            44082     0.001622
#            44646     0.001622
#            62828     0.001622
#            65642     0.001622
#                        ...
# Yes        341971    0.004219
#            350525    0.004219
#            377203    0.004219
#            531629    0.004219
#            539998    0.004219
# Name: proportion, Length: 1460, dtype: float64

# %% [markdown]
# ### Analyze if factors like overtime affect attrition rates

# %%
df.groupby(['Attrition'])['OverTime'].value_counts(normalize=True)
# Out:
# Attrition  OverTime
# No         No          0.765612
#            Yes         0.234388
# Yes        Yes         0.535865
#            No          0.464135
# Name: proportion, dtype: float64

# %% [markdown]
# ### Which departments have the highest or lowest average salaries.

# %%
df.groupby(['Department'])['Salary'].mean()
# Out:
# Department
# Human Resources    119698.809524
# Sales              119117.609865
# Technology         109655.122789
# Name: Salary, dtype: float64

# %% [markdown]
# ### Salary range within different job roles

# %%
df.groupby('JobRole')['Salary'].describe()
# Out:
#                            count           mean            std       min  \
# JobRole
# Analytics Manager           52.0  346484.230769  118080.676209  107863.0
# Data Scientist             261.0   56079.494253   43547.070678   20387.0
# Engineering Manager         75.0  286258.506667   91001.990610  115110.0
# HR Business Partner          7.0  314002.428571  104142.207510  190466.0
# HR Executive                28.0   94362.321429   43767.654180   41745.0
# HR Manager                   4.0  449330.750000   92157.549484  315071.0
# Machine Learning Engineer  146.0  130164.616438   76486.269014   39456.0
# Manager                     37.0  317531.054054   95375.631038  135407.0
# Recruiter                   24.0   37647.500000   15103.645094   20583.0
# Sales Executive            327.0  117195.538226   66723.920446   37035.0
# Sales Representative        83.0   40656.421687   16882.717082   20650.0
# Senior Software Engineer   132.0  126161.295455   72674.852989   36012.0
# ...

# %% [markdown]
# ### Gender balance in the organization.

# %%
df['Gender'].value_counts(normalize=True)
# Out:
# Gender
# Female               0.459184
# Male                 0.442857
# Non-Binary           0.084354
# Prefer Not To Say    0.013605
# Name: proportion, dtype: float64

# %% [markdown]
# ### Analyze salary differences between male and female employees.

# %%
df.groupby('Gender')['Salary'].mean()
# Out:
# Gender
# Female               113935.691852
# Male                 111773.809524
# Non-Binary           111395.508065
# Prefer Not To Say    128083.350000
# Name: Salary, dtype: float64

# %% [markdown]
# ### How many employees work overtime and which departments or job roles have more overtime?

# %%
df['OverTime'].value_counts()
# Out:
# OverTime
# No     1054
# Yes     416
# Name: count, dtype: int64

# %%
df.groupby('Department')['OverTime'].value_counts(normalize=True)
# Out:
# Department       OverTime
# Human Resources  No          0.730159
#                  Yes         0.269841
# Sales            No          0.713004
#                  Yes         0.286996
# Technology       No          0.718002
#                  Yes         0.281998
# Name: proportion, dtype: float64

# %%
df.groupby('JobRole')['OverTime'].value_counts(normalize=True)
# Out:
# JobRole                    OverTime
# Analytics Manager          No          0.769231
#                            Yes         0.230769
# Data Scientist             No          0.758621
#                            Yes         0.241379
# Engineering Manager        No          0.720000
#                            Yes         0.280000
# HR Business Partner        No          0.571429
#                            Yes         0.428571
# HR Executive               No          0.785714
#                            Yes         0.214286
# HR Manager                 No          0.750000
#                            Yes         0.250000
# Machine Learning Engineer  No          0.732877
#                            Yes         0.267123
# Manager                    No          0.729730
#                            Yes         0.270270
# Recruiter                  No          0.708333
#                            Yes         0.291667
# Sales Executive            No          0.709480
# ...

# %% [markdown]
# ### Does working overtime affects the likelihood of employees leaving the company?

# %%
df.groupby('OverTime')['Attrition'].value_counts(normalize=True)
# Out:
# OverTime  Attrition
# No        No           0.895636
#           Yes          0.104364
# Yes       No           0.694712
#           Yes          0.305288
# Name: proportion, dtype: float64

# %% [markdown]
# ### How long employees typically stay at the company?

# %%
df['YearsAtCompany'].mean()
# Out:
# 4.562585034013606

# %% [markdown]
# ### How often employees are promoted and if there are differences between departments?

# %%
df['YearsSinceLastPromotion'].mean()
# Out:
# 3.440816326530612

# %%
df.groupby('Department')['YearsSinceLastPromotion'].mean()
# Out:
# Department
# Human Resources    3.285714
# Sales              3.260090
# Technology         3.534860
# Name: YearsSinceLastPromotion, dtype: float64

# %% [markdown]
# ### Is there any relationship between the education field and the type of job roles employees hold?

# %%
df.groupby('EducationField')['JobRole'].value_counts()
# Out:
# EducationField       JobRole
# Business Studies     Software Engineer             39
#                      Data Scientist                19
#                      Machine Learning Engineer     14
#                      Senior Software Engineer      14
#                      Engineering Manager            5
#                      Analytics Manager              3
# Computer Science     Software Engineer            133
#                      Data Scientist               121
#                      Machine Learning Engineer     71
#                      Senior Software Engineer      61
#                      Engineering Manager           34
#                      Analytics Manager             20
# Economics            Sales Executive               65
#                      Sales Representative          18
#                      Recruiter                      6
#                      HR Executive                   5
#                      Manager                        5
# ...

# %% [markdown]
# ### How does different education levels affect salary?
#
# |EducationLevelID | EducationLevel |
# |:-----------------:|:----------------:|
# | 1 | No Formal Qualifications |
# | 2 | High School |
# | 3 | Bachelors |
# | 4 | Masters |
# | 5 | Doctorate |

# %%
df.groupby('Education')['Salary'].mean()
# Out:
# Education
# 1     94983.482353
# 2    105180.535461
# 3    115405.430070
# 4    117641.057789
# 5    154268.791667
# Name: Salary, dtype: float64

# %% [markdown]
# ### Are the employees who live farther away are more likely to leave?

# %%
df.groupby('Attrition')['DistanceFromHome (KM)'].mean()
# Out:
# Attrition
# No     22.557989
# Yes    22.215190
# Name: DistanceFromHome (KM), dtype: float64

# %%
da=[ 'BusinessTravel', 'Department', 'JobRole', 'MaritalStatus']
for i in da:
    print(i,':',df[i].unique())
    print('=======================================================================================')
# Out:
# BusinessTravel : ['Some Travel' 'No Travel ' 'Frequent Traveller']
# ...
# Department : ['Sales' 'Human Resources' 'Technology']
# ...
# JobRole : ['Sales Executive' 'HR Business Partner' 'Engineering Manager' 'Recruiter'
#  'Data Scientist' 'Machine Learning Engineer' 'Manager'
#  'Software Engineer' 'Senior Software Engineer' 'Sales Representative'
#  'Analytics Manager' 'HR Executive' 'HR Manager']
# ...
# MaritalStatus : ['Divorced' 'Single' 'Married']
# ...

# %% [markdown]
# ## Demographic Analysis

# %% [markdown]
# ### Gender Distribution

# %%
df['Gender'].value_counts().plot(kind = 'bar', title = 'Gender Distribution')
# Out:
# <Axes: title={'center': 'Gender Distribution'}, xlabel='Gender'>

# %% [markdown]
# ### Age Distribution

# %%
df['Age'].plot(kind = 'hist',bins = 20, title = 'Age Distribution', color = 'lightgreen')
# Out:
# <Axes: title={'center': 'Age Distribution'}, ylabel='Frequency'>

# %% [markdown]
# ### Ethinicity Breakdown

# %%
df['Ethnicity'].value_counts().plot(kind = 'pie', autopct = '%1.1f%%', title = 'Ethinicity Breakdown')
# Out:
# <Axes: title={'center': 'Ethinicity Breakdown'}, ylabel='count'>

# %% [markdown]
# ### Education Levels
#
# |EducationLevelID | EducationLevel |
# |:-----------------:|:----------------:|
# | 1 | No Formal Qualifications |
# | 2 | High School |
# | 3 | Bachelors |
# | 4 | Masters |
# | 5 | Doctorate |

# %%
df['Education'].value_counts().sort_index().plot(kind='bar', title='Education Level Distribution')
# Out:
# <Axes: title={'center': 'Education Level Distribution'}, xlabel='Education'>

# %% [markdown]
# ### Marital Status

# %%
df['MaritalStatus'].value_counts().plot(kind='bar', title='Marital Status Distribution', color='coral')
# Out:
# <Axes: title={'center': 'Marital Status Distribution'}, xlabel='MaritalStatus'>

# %% [markdown]
# ### Department-wise Employee Count

# %%
df['Department'].value_counts().plot(kind = 'bar', title = 'Employees per Department', color = 'green')
# Out:
# <Axes: title={'center': 'Employees per Department'}, xlabel='Department'>

# %% [markdown]
# ### Job Role Distribution

# %%
df['JobRole'].value_counts().plot(kind = 'barh', title = 'Job Role Distribution', figsize = (8,5))
# Out:
# <Axes: title={'center': 'Job Role Distribution'}, ylabel='JobRole'>

# %% [markdown]
# ### Business Travel Frequency

# %%
df['BusinessTravel'].value_counts().plot(kind = 'bar', title='Business Travel Frequency', color = 'magenta')
# Out:
# <Axes: title={'center': 'Business Travel Frequency'}, xlabel='BusinessTravel'>

# %% [markdown]
# ### Number of Years at COmpany distribution

# %%
df['YearsAtCompany'].plot(kind = 'hist', bins = 15, title = 'Years at Company Distribution', color = 'orange')
# Out:
# <Axes: title={'center': 'Years at Company Distribution'}, ylabel='Frequency'>

# %% [markdown]
# ### Years Since Last Promotion

# %%
df['YearsSinceLastPromotion'].plot(kind = 'hist', bins = 10, title = 'Years Since Last Promotion', color = 'teal')
# Out:
# <Axes: title={'center': 'Years Since Last Promotion'}, ylabel='Frequency'>

# %% [markdown]
# ### Salary Distribution

# %%
df['Salary'].plot(kind = 'hist', bins = 20, title = 'Salary Distribution', color = 'navy')
# Out:
# <Axes: title={'center': 'Salary Distribution'}, ylabel='Frequency'>

# %% [markdown]
# ### Salary by Department

# %%
df.groupby('Department')['Salary'].mean().plot(kind = 'bar', title = 'Salary by Department', color = 'darkcyan')
# Out:
# <Axes: title={'center': 'Salary by Department'}, xlabel='Department'>

# %% [markdown]
# ### Salary by Job Role

# %%
df.groupby('JobRole')['Salary'].mean().sort_values().plot(kind = 'barh', title = 'Average Salary by Job Role', color = 'olive')
# Out:
# <Axes: title={'center': 'Average Salary by Job Role'}, ylabel='JobRole'>

# %% [markdown]
# ### Salary vs Years At Complany

# %%
plt.scatter(df['YearsAtCompany'], df['Salary'], alpha = 0.5, color = 'Magenta')
plt.xlabel('Years at Company')
plt.ylabel('Salary')
plt.title('Salary vs Years at Company')
plt.show()

# %% [markdown]
# ## Overall Attrition Rate

# %%
df['Attrition'].value_counts().plot(kind = 'pie', autopct = '%1.1f%%', title = 'Overall Attrition Rate')
# Out:
# <Axes: title={'center': 'Overall Attrition Rate'}, ylabel='count'>

# %% [markdown]
# ### Attrition by Department

# %%
abd = df.groupby('Department')['Attrition'].value_counts(normalize = True).unstack() * 100
abd.plot(kind = 'bar', stacked = True, title = 'Attrition by Department', color = ['lightgreen', 'salmon'])
# Out:
# <Axes: title={'center': 'Attrition by Department'}, xlabel='Department'>

# %% [markdown]
# ### Attrition vs Overtime

# %%
sns.countplot(x = 'OverTime', hue = 'Attrition', data = df)
plt.title('Attrition vs Overtime')
# Out:
# Text(0.5, 1.0, 'Attrition vs Overtime')

# %% [markdown]
# ### Attrition vs Salary

# %%
sns.boxplot(x = 'Attrition', y = 'Salary', data = df)
plt.title('Attrition vs Salary')
# Out:
# Text(0.5, 1.0, 'Attrition vs Salary')

# %% [markdown]
# ### Attrition vs Years Since Last Promotion

# %%
sns.boxplot(x = 'Attrition', y = 'YearsSinceLastPromotion', data = df)
plt.title('Attrition vs Years Since Last Promotion')
# Out:
# Text(0.5, 1.0, 'Attrition vs Years Since Last Promotion')

# %% [markdown]
# ## Correlation Heatmap

# %%
numeric_cols = ['Age', 'DistanceFromHome (KM)', 'Education', 'Salary',
                'StockOptionLevel', 'YearsAtCompany', 'YearsInMostRecentRole',
                'YearsSinceLastPromotion', 'YearsWithCurrManager']
corr_matrix = df[numeric_cols].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix of Numerical Features');

# %% [markdown]
# ## Data Model Building

# %% [markdown]
# ### Import Required Libraries

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report
from sklearn.linear_model import LogisticRegression

# %%
categorical_cols = ['Gender', 'BusinessTravel', 'Department', 'State',
                    'Ethnicity','EducationField', 'JobRole',
                    'MaritalStatus', 'OverTime']

# %% [markdown]
# ### Calculating Chi-Square Values

# %%
from scipy.stats import chi2_contingency
for col in categorical_cols:
    contingency_table = pd.crosstab(df[col], df['Attrition'])
    chi2, p, dof, ex = chi2_contingency(contingency_table)
    print(f"Chi-Square test between 'Attrition' and '{col}': p-value = {p}")
# Out:
# Chi-Square test between 'Attrition' and 'Gender': p-value = 0.16553489004194544
# Chi-Square test between 'Attrition' and 'BusinessTravel': p-value = 5.608614476449931e-06
# Chi-Square test between 'Attrition' and 'Department': p-value = 0.004525606574479633
# Chi-Square test between 'Attrition' and 'State': p-value = 0.2175949355874725
# Chi-Square test between 'Attrition' and 'Ethnicity': p-value = 0.8582053939739726
# Chi-Square test between 'Attrition' and 'EducationField': p-value = 0.008363170391067572
# Chi-Square test between 'Attrition' and 'JobRole': p-value = 2.1898966200983104e-14
# Chi-Square test between 'Attrition' and 'MaritalStatus': p-value = 3.229218243754594e-08
# Chi-Square test between 'Attrition' and 'OverTime': p-value = 8.15842372153832e-21

# %% [markdown]
# - Features like BusinessTravel, JobRole, OverTime, and MaritalStatus have very low p-values and should be considered as strong predictors for 'Attrition'.
#
# - Features like Department, EducationField, though significant, might have weaker associations. Depending on model performance, you may decide to keep or exclude them.
#
# - Features with high p-values (e.g., Gender, State, Ethnicity) might not contribute much to the model.

# %%
df['Attrition'].replace({'No':0,'Yes':1},inplace=True)

# %%
print(df['Attrition'].head())
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    1
# Name: Attrition, dtype: int64

# %%
numeric_data = df.select_dtypes(include=['number'])
numeric_data
# Out:
#       Age  DistanceFromHome (KM)  Education  Salary  StockOptionLevel  \
# 0      30                     27          5  102059                 1
# 1      38                     23          4  157718                 0
# 2      43                     29          4  309964                 1
# 3      39                     12          3  293132                 0
# 4      29                     29          2   49606                 0
# ...   ...                    ...        ...     ...               ...
# 1465   20                     28          2   38508                 0
# 1466   27                      8          3   92995                 3
# 1467   21                      4          4   63375                 0
# 1468   21                      7          3   46521                 0
# 1469   20                     28          2   38258                 0
#
#       Attrition  YearsAtCompany  YearsInMostRecentRole  \
# 0             0              10                      4
# ...

# %% [markdown]
# ### Correlation Matrix

# %%
correlation_matrix = numeric_data.corr()
correlation_matrix
# Out:
#                               Age  DistanceFromHome (KM)  Education    Salary  \
# Age                      1.000000               0.022892  -0.011168  0.529227
# DistanceFromHome (KM)    0.022892               1.000000   0.010706  0.052306
# Education               -0.011168               0.010706   1.000000  0.090907
# Salary                   0.529227               0.052306   0.090907  1.000000
# StockOptionLevel         0.007587               0.020537   0.018422 -0.006282
# Attrition               -0.134413              -0.009843  -0.031373 -0.130263
# YearsAtCompany           0.543169              -0.035646  -0.055386  0.106143
# YearsInMostRecentRole    0.364278              -0.031279  -0.044887  0.049874
# YearsSinceLastPromotion  0.466852              -0.049069  -0.060612  0.076502
# YearsWithCurrManager     0.402946              -0.008842  -0.068794  0.067176
#
#                          StockOptionLevel  Attrition  YearsAtCompany  \
# ...

# %%
correlation_with_target = correlation_matrix['Attrition'].sort_values(ascending=False)
print(correlation_with_target)
# Out:
# Attrition                  1.000000
# DistanceFromHome (KM)     -0.009843
# Education                 -0.031373
# Salary                    -0.130263
# Age                       -0.134413
# StockOptionLevel          -0.137145
# YearsWithCurrManager      -0.219889
# YearsInMostRecentRole     -0.224829
# YearsAtCompany            -0.284964
# YearsSinceLastPromotion   -0.297491
# Name: Attrition, dtype: float64

# %% [markdown]
# - The feature YearsSinceLastPromotion has the strongest negative correlation with 'Attrition', indicating that employees who have not been promoted recently are more likely to leave.
#
# - Features like DistanceFromHome and Education have very weak correlations with 'Attrition', suggesting they have minimal impact.

# %% [markdown]
# ### Splitting of Dataset / Dataframe

# %%
x = df.iloc[:,4:]

# %%
x.columns
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1470 non-null   int64
#  1   BusinessTravel           1470 non-null   object
#  2   Department               1470 non-null   object
#  3   DistanceFromHome (KM)    1470 non-null   int64
#  4   State                    1470 non-null   object
#  5   Ethnicity                1470 non-null   object
#  6   Education                1470 non-null   int64
#  7   EducationField           1470 non-null   object
#  8   JobRole                  1470 non-null   object
#  9   MaritalStatus            1470 non-null   object
#  10  Salary                   1470 non-null   int64
#  11  StockOptionLevel         1470 non-null   int64
#  12  OverTime                 1470 non-null   object
#  13  HireDate                 1470 non-null   datetime64[ns]
# ...

# %%
x.drop(columns=['HireDate','Attrition','State','Ethnicity', 'Education',
                'EducationField','DistanceFromHome (KM)','StockOptionLevel',
                'YearsWithCurrManager'],inplace=True)

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1470 non-null   int64
#  1   BusinessTravel           1470 non-null   object
#  2   Department               1470 non-null   object
#  3   JobRole                  1470 non-null   object
#  4   MaritalStatus            1470 non-null   object
#  5   Salary                   1470 non-null   int64
#  6   OverTime                 1470 non-null   object
#  7   YearsAtCompany           1470 non-null   int64
#  8   YearsInMostRecentRole    1470 non-null   int64
#  9   YearsSinceLastPromotion  1470 non-null   int64
# dtypes: int64(5), object(5)
# memory usage: 115.0+ KB

# %%
y = df['Attrition']
y.value_counts()
# Out:
# Attrition
# 0    1233
# 1     237
# Name: count, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.reset_index(drop=True)
# Out:
#       Age      BusinessTravel  Department            JobRole MaritalStatus  \
# 0      23         Some Travel  Technology     Data Scientist      Divorced
# 1      23         Some Travel  Technology  Software Engineer      Divorced
# 2      30         Some Travel  Technology     Data Scientist       Married
# 3      21         Some Travel  Technology  Software Engineer      Divorced
# 4      21         Some Travel  Technology     Data Scientist       Married
# ...   ...                 ...         ...                ...           ...
# 1171   21  Frequent Traveller  Technology  Software Engineer        Single
# 1172   31         Some Travel       Sales    Sales Executive       Married
# 1173   24         Some Travel  Technology  Software Engineer      Divorced
# 1174   19         Some Travel  Technology     Data Scientist        Single
# 1175   22  Frequent Traveller  Technology     Data Scientist      Divorced
#
#       Salary OverTime  YearsAtCompany  YearsInMostRecentRole  \
# ...

# %%
x_train.nunique()
# Out:
# Age                          33
# BusinessTravel                3
# Department                    3
# JobRole                      13
# MaritalStatus                 3
# Salary                     1166
# OverTime                      2
# YearsAtCompany               11
# YearsInMostRecentRole        11
# YearsSinceLastPromotion      11
# dtype: int64

# %%
df['Attrition'].value_counts()
# Out:
# Attrition
# 0    1233
# 1     237
# Name: count, dtype: int64
